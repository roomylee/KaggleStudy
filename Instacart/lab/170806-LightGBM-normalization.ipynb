# %% [markdown]
# # Normalization with LightGBM

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 0. Introduction of Data

# %%
products = pd.read_csv("../data/products.csv")
aisles = pd.read_csv("../data/aisles.csv")
departments = pd.read_csv("../data/departments.csv")
orders = pd.read_csv("../data/orders.csv")
prior = pd.read_csv("../data/order_products__prior.csv")
train = pd.read_csv("../data/order_products__train.csv")
frame_train = pd.read_csv("../data/frame_train.csv")
frame_test = pd.read_csv("../data/frame_test.csv")
userXproduct = pd.read_csv("../data/userXproduct.csv")

# %% [markdown]
# ### orders.csv

# %%
print("Size of orders : ", len(orders))
orders.head()
# Out:
# Size of orders :  3421083
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ### order_products_prior.csv

# %%
print("Size of prior : ", len(prior))
prior.head()
# Out:
# Size of prior :  32434489
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %% [markdown]
# ### products.csv

# %%
print("Size of Products : ", len(products))
products.head()
# Out:
# Size of Products :  49688
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %% [markdown]
# ### frame_train.csv

# %%
print("Size of frame of train : ", len(frame_train))
frame_train.head()
# Out:
# Size of frame of train :  8474661
#    user_id  order_id  product_id  products
# 0        1   1187899       17122         0
# 1        1   1187899         196         1
# 2        1   1187899       26405         1
# 3        1   1187899       46149         1
# 4        1   1187899       14084         0

# %% [markdown]
# # 1. orders Information - categorization of order hour

# %%
orders.set_index('order_id', inplace=True, drop=False)

# %%
orders['categorized_order_hour_of_day'] = 0
orders.loc[orders['order_hour_of_day']>=9,'categorized_order_hour_of_day'] = 1
orders.loc[orders['order_hour_of_day']>=13,'categorized_order_hour_of_day'] = 2
orders.loc[orders['order_hour_of_day']>=19,'categorized_order_hour_of_day'] = 3
orders.head()
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# order_id
# 2539329    2539329        1    prior             1          2
# 2398795    2398795        1    prior             2          3
# 473747      473747        1    prior             3          3
# 2254736    2254736        1    prior             4          4
# 431534      431534        1    prior             5          4
#
#           order_hour_of_day  days_since_prior_order  \
# order_id
# 2539329                   8                     NaN
# 2398795                   7                    15.0
# 473747                   12                    21.0
# 2254736                   7                    29.0
# 431534                   15                    28.0
#
#           categorized_order_hour_of_day
# order_id
# 2539329                               0
# 2398795                               0
# 473747                                1
# 2254736                               0
# 431534                                2

# %%
orders = orders.join(pd.get_dummies(orders['categorized_order_hour_of_day'], prefix='categorized_hour'))
orders.drop(['categorized_order_hour_of_day'], axis=1, inplace=True)

# %%
orders.head()
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# order_id
# 2539329    2539329        1    prior             1          2
# 2398795    2398795        1    prior             2          3
# 473747      473747        1    prior             3          3
# 2254736    2254736        1    prior             4          4
# 431534      431534        1    prior             5          4
#
#           order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# order_id
# 2539329                   8                     NaN                   1
# 2398795                   7                    15.0                   1
# 473747                   12                    21.0                   0
# 2254736                   7                    29.0                   1
# 431534                   15                    28.0                   0
#
#           categorized_hour_1  categorized_hour_2  categorized_hour_3
# order_id
# 2539329                    0                   0                   0
# 2398795                    0                   0                   0
# 473747                     1                   0                   0
# 2254736                    0                   0                   0
# 431534                     0                   1                   0

# %% [markdown]
# # 2. Integrate Products Information
# * products와 prior에서 얻을 수 있는 제품 관련 정보를 통합
# * 기존의 attribute인 product_id, product_name, aisle_id, department_id
# * 여기에 prior에서 얻을 수 있는 해당 제품에 판매에 관련된 attribute를 추가
# * 총주문량(total_orders), 총재주문량(total_reorders), 재주문율(reorder_rate)을 추가함

# %%
productsXprior = pd.DataFrame()
productsXprior['product_id'] = prior.groupby(prior.product_id).size().index
productsXprior['product_orders'] = prior.groupby(prior.product_id).size().values
productsXprior['product_reorders'] = prior['reordered'].groupby(prior.product_id).sum().values
productsXprior['product_reorder_rate'] = (productsXprior.product_reorders / productsXprior.product_orders)
print("Size of productsXprior : ", len(productsXprior))
productsXprior.head()
# Out:
# Size of productsXprior :  49677
#    product_id  product_orders  product_reorders  product_reorder_rate
# 0           1            1852              1136              0.613391
# 1           2              90                12              0.133333
# 2           3             277               203              0.732852
# 3           4             329               147              0.446809
# 4           5              15                 9              0.600000

# %%
Products = products.merge(productsXprior, on='product_id', how='outer')
print("Size of Products : ", len(Products))
Products.head()
# Out:
# Size of Products :  49688
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  product_orders  product_reorders  product_reorder_rate
# 0             19          1852.0            1136.0              0.613391
# 1             13            90.0              12.0              0.133333
# 2              7           277.0             203.0              0.732852
# 3              1           329.0             147.0              0.446809
# 4             13            15.0               9.0              0.600000

# %%
Products[Products.isnull().any(axis=1)]
# Out:
#        product_id                                       product_name  \
# 3629         3630                        Protein Granola Apple Crisp
# 3717         3718                   Wasabi Cheddar Spreadable Cheese
# 7044         7045             Unpeeled Apricot Halves in Heavy Syrup
# 25382       25383                                 Chocolate Go Bites
# 27498       27499                  Non-Dairy Coconut Seven Layer Bar
# 36232       36233                            Water With Electrolytes
# 37702       37703  Ultra Sun Blossom Liquid 90 loads Fabric Enhan...
# 43724       43725                               Sweetart Jelly Beans
# 45970       45971                         12 Inch Taper Candle White
# 46624       46625    Single Barrel Kentucky Straight Bourbon Whiskey
# 49539       49540                            Pure Squeezed  Lemonade
#
#        aisle_id  department_id  product_orders  product_reorders  \
# 3629         57             14             NaN               NaN
# 3717         21             16             NaN               NaN
# 7044         88             13             NaN               NaN
# 25382        61             19             NaN               NaN
# 27498       100             21             NaN               NaN
# 36232       100             21             NaN               NaN
# 37702        75             17             NaN               NaN
# 43724       100             21             NaN               NaN
# 45970       101             17             NaN               NaN
# 46624        31              7             NaN               NaN
# 49539        31              7             NaN               NaN
#
#        product_reorder_rate
# 3629                    NaN
# 3717                    NaN
# 7044                    NaN
# 25382                   NaN
# 27498                   NaN
# 36232                   NaN
# 37702                   NaN
# 43724                   NaN
# 45970                   NaN
# 46624                   NaN
# 49539                   NaN

# %%
Products = Products.replace(np.NaN, 0)
print("Size of Products : ", len(Products))
Products.head()
# Out:
# Size of Products :  49688
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  product_orders  product_reorders  product_reorder_rate
# 0             19          1852.0            1136.0              0.613391
# 1             13            90.0              12.0              0.133333
# 2              7           277.0             203.0              0.732852
# 3              1           329.0             147.0              0.446809
# 4             13            15.0               9.0              0.600000

# %% [markdown]
# # 3. Integrate_Users_Information
# * prior와 orders를 통합(priorXorders)하여 user_id, order_id, product_id를 하나로 모음.
# * priorXorders를 기반으로 하여 유저 정보를 담고 있는 Users를 생성.

# %%
priorXorders = prior.merge(orders, on='order_id')
print("Size of Prior : ", len(priorXorders))
priorXorders.head()
# Out:
# Size of Prior :  32434489
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0
#
#    categorized_hour_0  categorized_hour_1  categorized_hour_2  \
# 0                   0                   1                   0
# 1                   0                   1                   0
# 2                   0                   1                   0
# 3                   0                   1                   0
# 4                   0                   1                   0
#
#    categorized_hour_3
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
user_orders = pd.DataFrame()
user_orders['user_avg_orders_period'] = orders.groupby('user_id')['days_since_prior_order'].mean()
user_orders['user_total_orders'] = orders.groupby('user_id').size()

user_orders['user_id'] = user_orders.index
user_orders.index.name = None

print("Size of user_orders : ", len(user_orders))
user_orders.head()
# Out:
# Size of user_orders :  206209
#    user_avg_orders_period  user_total_orders  user_id
# 1               19.000000                 11        1
# 2               16.285714                 15        2
# 3               12.000000                 13        3
# 4               17.000000                  6        4
# 5               11.500000                  5        5

# %%
user_prior = pd.DataFrame()
user_prior['user_total_products'] = priorXorders.groupby('user_id').size()
user_prior['ordered_products_set'] = priorXorders.groupby('user_id')['product_id'].apply(set)
user_prior['user_unique_products'] = (user_prior.ordered_products_set.map(len))
user_prior = user_prior[['user_total_products', 'user_unique_products', 'ordered_products_set']]

user_prior['user_id'] = user_prior.index
user_prior.index.name = None

print("Size of user_prior : ", len(user_prior))
user_prior.head()
# Out:
# Size of user_prior :  206209
#    user_total_products  user_unique_products  \
# 1                   59                    18
# 2                  195                   102
# 3                   88                    33
# 4                   18                    17
# 5                   37                    23
#
#                                 ordered_products_set  user_id
# 1  {17122, 196, 26405, 46149, 14084, 13032, 26088...        1
# 2  {45066, 2573, 18961, 23, 32792, 1559, 22559, 1...        2
# 3  {17668, 44683, 48523, 21903, 14992, 21137, 324...        3
# 4  {21573, 42329, 17769, 35469, 37646, 1200, 1905...        4
# 5  {11777, 40706, 28289, 48775, 20754, 6808, 1398...        5

# %%
Users = user_prior.merge(user_orders, on='user_id')
print("Size of users : ", len(Users))
Users.head()
# Out:
# Size of users :  206209
#    user_total_products  user_unique_products  \
# 0                   59                    18
# 1                  195                   102
# 2                   88                    33
# 3                   18                    17
# 4                   37                    23
#
#                                 ordered_products_set  user_id  \
# 0  {17122, 196, 26405, 46149, 14084, 13032, 26088...        1
# 1  {45066, 2573, 18961, 23, 32792, 1559, 22559, 1...        2
# 2  {17668, 44683, 48523, 21903, 14992, 21137, 324...        3
# 3  {21573, 42329, 17769, 35469, 37646, 1200, 1905...        4
# 4  {11777, 40706, 28289, 48775, 20754, 6808, 1398...        5
#
#    user_avg_orders_period  user_total_orders
# 0               19.000000                 11
# 1               16.285714                 15
# 2               12.000000                 13
# 3               17.000000                  6
# 4               11.500000                  5

# %%
Users['user_avg_cart'] = (Users.user_total_products / (Users.user_total_orders - 1))
print("Size of users : ", len(Users))
Users.head()
# Out:
# Size of users :  206209
#    user_total_products  user_unique_products  \
# 0                   59                    18
# 1                  195                   102
# 2                   88                    33
# 3                   18                    17
# 4                   37                    23
#
#                                 ordered_products_set  user_id  \
# 0  {17122, 196, 26405, 46149, 14084, 13032, 26088...        1
# 1  {45066, 2573, 18961, 23, 32792, 1559, 22559, 1...        2
# 2  {17668, 44683, 48523, 21903, 14992, 21137, 324...        3
# 3  {21573, 42329, 17769, 35469, 37646, 1200, 1905...        4
# 4  {11777, 40706, 28289, 48775, 20754, 6808, 1398...        5
#
#    user_avg_orders_period  user_total_orders  user_avg_cart
# 0               19.000000                 11       5.900000
# 1               16.285714                 15      13.928571
# 2               12.000000                 13       7.333333
# 3               17.000000                  6       3.600000
# 4               11.500000                  5       9.250000

# %% [markdown]
# # normalization Users['user_unique_products']

# %%
Users['user_total_products'] =(Users['user_total_products']-Users['user_total_products'].mean())/(Users['user_total_products'].std())
Users['user_unique_products'] =(Users['user_unique_products']-Users['user_unique_products'].mean())/(Users['user_unique_products'].std())


Users.head()
# Out:
#    user_total_products  user_unique_products  \
# 0             0.015046              0.023448
# 1             0.051585              0.139310
# 2             0.022837              0.044138
# 3             0.004030              0.022069
# 4             0.009135              0.030345
#
#                                 ordered_products_set  user_id  \
# 0  {17122, 196, 26405, 46149, 14084, 13032, 26088...        1
# 1  {45066, 2573, 18961, 23, 32792, 1559, 22559, 1...        2
# 2  {17668, 44683, 48523, 21903, 14992, 21137, 324...        3
# 3  {21573, 42329, 17769, 35469, 37646, 1200, 1905...        4
# 4  {11777, 40706, 28289, 48775, 20754, 6808, 1398...        5
#
#    user_avg_orders_period  user_total_orders  user_avg_cart
# 0               19.000000                 11       5.900000
# 1               16.285714                 15      13.928571
# 2               12.000000                 13       7.333333
# 3               17.000000                  6       3.600000
# 4               11.500000                  5       9.250000

# %% [markdown]
# # 4. UP(userXproduct) Information

# %%
userXproduct.columns = ['user_product','UP_orders','UP_last_order_id','UP_sum_pos_in_cart']
print('Size of user X product', len(userXproduct))
userXproduct.head()
# Out:
# Size of user X product 13307953
#    user_product  UP_orders  UP_last_order_id  UP_sum_pos_in_cart
# 0   14126415872          5            843810                  63
# 1   20535312385          1           2699553                   9
# 2    1375731717          7           2844957                  51
# 3    8959033352          4           1924807                  57
# 4    7342828204          3            723315                  13

# %% [markdown]
# # 5. Train Data Generation
# * ### 미리 만들어 둔 frame_train을 기반으로 위의 orders, Products, Users 정보를 통합시켜 train data를 만듬.
# * order_prior, order_train은 학습데이터로 포함 X, order_test가 없기 때문에 test데이터에 해당 attribute를 포함시킬 수 없음.

# %%
train_df = frame_train.copy()
train_df.set_index(['user_id','order_id','product_id']).head(10)
# Out:
#                              products
# user_id order_id product_id
# 1       1187899  17122              0
#                  196                1
#                  26405              1
#                  46149              1
#                  14084              0
#                  13032              1
#                  26088              1
#                  39657              1
#                  12427              0
#                  25133              1

# %% [markdown]
# ### 1) orders Information 통합

# %%
train_df = train_df.merge(orders, how='left', on=['user_id','order_id'])
train_df.head()
# Out:
#    user_id  order_id  product_id  products eval_set  order_number  order_dow  \
# 0        1   1187899       17122         0    train            11          4
# 1        1   1187899         196         1    train            11          4
# 2        1   1187899       26405         1    train            11          4
# 3        1   1187899       46149         1    train            11          4
# 4        1   1187899       14084         0    train            11          4
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# 0                  8                    14.0                   1
# 1                  8                    14.0                   1
# 2                  8                    14.0                   1
# 3                  8                    14.0                   1
# 4                  8                    14.0                   1
#
#    categorized_hour_1  categorized_hour_2  categorized_hour_3
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0

# %% [markdown]
# ### 2) Products Information 통합

# %%
train_df = train_df.merge(Products, how='left', on='product_id')
train_df.head()
# Out:
#    user_id  order_id  product_id  products eval_set  order_number  order_dow  \
# 0        1   1187899       17122         0    train            11          4
# 1        1   1187899         196         1    train            11          4
# 2        1   1187899       26405         1    train            11          4
# 3        1   1187899       46149         1    train            11          4
# 4        1   1187899       14084         0    train            11          4
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# 0                  8                    14.0                   1
# 1                  8                    14.0                   1
# 2                  8                    14.0                   1
# 3                  8                    14.0                   1
# 4                  8                    14.0                   1
#
#    categorized_hour_1  categorized_hour_2  categorized_hour_3  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#                               product_name  aisle_id  department_id  \
# 0                        Honeycrisp Apples        24              4
# 1                                     Soda        77              7
# 2         XL Pick-A-Size Paper Towel Rolls        54             17
# 3                        Zero Calorie Cola        77              7
# 4  Organic Unsweetened Vanilla Almond Milk        91             16
#
#    product_orders  product_reorders  product_reorder_rate  \
# 0         13880.0            9377.0              0.675576
# 1         35791.0           27791.0              0.776480
# 2          1214.0             536.0              0.441516
# 3          8558.0            6953.0              0.812456
# 4         15935.0           12923.0              0.810982
#
#    norm_product_reorders
# 0               0.023524
# 1               0.069720
# 2               0.001345
# 3               0.017443
# 4               0.032420

# %% [markdown]
# ### 3) Users Information 통합

# %%
train_df = train_df.merge(Users, how='left', on='user_id')
train_df.head()
# Out:
#    user_id  order_id  product_id  products eval_set  order_number  order_dow  \
# 0        1   1187899       17122         0    train            11          4
# 1        1   1187899         196         1    train            11          4
# 2        1   1187899       26405         1    train            11          4
# 3        1   1187899       46149         1    train            11          4
# 4        1   1187899       14084         0    train            11          4
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# 0                  8                    14.0                   1
# 1                  8                    14.0                   1
# 2                  8                    14.0                   1
# 3                  8                    14.0                   1
# 4                  8                    14.0                   1
#
#        ...        product_orders  product_reorders  product_reorder_rate  \
# 0      ...               13880.0            9377.0              0.675576
# 1      ...               35791.0           27791.0              0.776480
# 2      ...                1214.0             536.0              0.441516
# 3      ...                8558.0            6953.0              0.812456
# 4      ...               15935.0           12923.0              0.810982
#
#   norm_product_reorders  user_total_products  user_unique_products  \
# 0              0.023524             0.015046              0.023448
# 1              0.069720             0.015046              0.023448
# 2              0.001345             0.015046              0.023448
# 3              0.017443             0.015046              0.023448
# 4              0.032420             0.015046              0.023448
#
#                                 ordered_products_set  user_avg_orders_period  \
# 0  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
# 1  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
# 2  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
# 3  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
# 4  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
#
#    user_total_orders  user_avg_cart
# 0                 11            5.9
# 1                 11            5.9
# 2                 11            5.9
# 3                 11            5.9
# 4                 11            5.9
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Extra Feature) days_since_ratio 추가

# %%
train_df['days_since_ratio'] = train_df.days_since_prior_order / train_df.user_avg_orders_period

# %% [markdown]
# ### 4) UP(userXproduct) Information 추가

# %%
train_df['user_product'] = train_df.user_id * 100000 + train_df.product_id
train_df = train_df.merge(userXproduct, how='left', on='user_product')
train_df.drop(['user_product'], axis=1, inplace=True)

# %%
train_df['UP_orders_ratio'] = train_df.UP_orders / train_df.user_total_orders
train_df['UP_avg_pos_in_cart'] = train_df.UP_sum_pos_in_cart / train_df.UP_orders
train_df['UP_reorder_rate'] = train_df.UP_orders / train_df.user_total_orders
train_df['UP_orders_since_last'] = train_df.user_total_orders - train_df.UP_last_order_id.map(orders.order_number)
train_df['UP_delta_hour_vs_last'] = abs(train_df.order_hour_of_day - train_df.UP_last_order_id.map(orders.order_hour_of_day)).map(lambda x: min(x, 24-x))

train_df.head()
# Out:
#    user_id  order_id  product_id  products eval_set  order_number  order_dow  \
# 0        1   1187899       17122         0    train            11          4
# 1        1   1187899         196         1    train            11          4
# 2        1   1187899       26405         1    train            11          4
# 3        1   1187899       46149         1    train            11          4
# 4        1   1187899       14084         0    train            11          4
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# 0                  8                    14.0                   1
# 1                  8                    14.0                   1
# 2                  8                    14.0                   1
# 3                  8                    14.0                   1
# 4                  8                    14.0                   1
#
#            ...            user_avg_cart  days_since_ratio  UP_orders  \
# 0          ...                      5.9          0.736842          1
# 1          ...                      5.9          0.736842         10
# 2          ...                      5.9          0.736842          2
# 3          ...                      5.9          0.736842          3
# 4          ...                      5.9          0.736842          1
#
#   UP_last_order_id  UP_sum_pos_in_cart  UP_orders_ratio  UP_avg_pos_in_cart  \
# 0           431534                   6         0.090909                 6.0
# 1          2550362                  14         0.909091                 1.4
# 2          2254736                  10         0.181818                 5.0
# 3          2550362                   9         0.272727                 3.0
# 4          2539329                   2         0.090909                 2.0
#
#    UP_reorder_rate  UP_orders_since_last  UP_delta_hour_vs_last
# 0         0.090909                     6                      7
# 1         0.909091                     1                      0
# 2         0.181818                     7                      1
# 3         0.272727                     1                      0
# 4         0.090909                    10                      0
#
# [5 rows x 35 columns]

# %% [markdown]
# # normalization train_df['UP_orders_since_last']

# %%
train_mean = train_df['UP_orders_since_last'].mean()
train_std = train_df['UP_orders_since_last'].std()
train_df['UP_orders_since_last'] =(train_df['UP_orders_since_last']-train_df['UP_orders_since_last'].mean())/(train_df['UP_orders_since_last'].std())

train_df[['UP_orders_since_last','user_unique_products','user_total_products']]
# Out:
#          UP_orders_since_last  user_unique_products  user_total_products
# 0                    0.051020              0.023448             0.015046
# 1                    0.000000              0.023448             0.015046
# 2                    0.061224              0.023448             0.015046
# 3                    0.000000              0.023448             0.015046
# 4                    0.091837              0.023448             0.015046
# 5                    0.000000              0.023448             0.015046
# 6                    0.081633              0.023448             0.015046
# 7                    0.000000              0.023448             0.015046
# 8                    0.000000              0.023448             0.015046
# 9                    0.000000              0.023448             0.015046
# 10                   0.000000              0.023448             0.015046
# 11                   0.000000              0.023448             0.015046
# 12                   0.000000              0.023448             0.015046
# 13                   0.071429              0.023448             0.015046
# 14                   0.010204              0.023448             0.015046
# 15                   0.051020              0.023448             0.015046
# 16                   0.051020              0.023448             0.015046
# 17                   0.051020              0.023448             0.015046
# 18                   0.071429              0.139310             0.051585
# 19                   0.000000              0.139310             0.051585
# 20                   0.051020              0.139310             0.051585
# 21                   0.061224              0.139310             0.051585
# 22                   0.020408              0.139310             0.051585
# 23                   0.000000              0.139310             0.051585
# 24                   0.051020              0.139310             0.051585
# 25                   0.020408              0.139310             0.051585
# 26                   0.091837              0.139310             0.051585
# 27                   0.051020              0.139310             0.051585
# 28                   0.020408              0.139310             0.051585
# 29                   0.132653              0.139310             0.051585
# ...                       ...                   ...                  ...
# 8474631              0.102041              0.092414             0.033853
# 8474632              0.102041              0.092414             0.033853
# 8474633              0.102041              0.092414             0.033853
# 8474634              0.051020              0.092414             0.033853
# 8474635              0.051020              0.092414             0.033853
# 8474636              0.051020              0.092414             0.033853
# 8474637              0.010204              0.092414             0.033853
# 8474638              0.061224              0.092414             0.033853
# 8474639              0.010204              0.092414             0.033853
# 8474640              0.091837              0.092414             0.033853
# 8474641              0.010204              0.092414             0.033853
# 8474642              0.112245              0.092414             0.033853
# 8474643              0.122449              0.092414             0.033853
# 8474644              0.061224              0.092414             0.033853
# 8474645              0.010204              0.092414             0.033853
# 8474646              0.102041              0.092414             0.033853
# 8474647              0.112245              0.092414             0.033853
# 8474648              0.020408              0.092414             0.033853
# 8474649              0.061224              0.092414             0.033853
# 8474650              0.051020              0.092414             0.033853
# 8474651              0.000000              0.092414             0.033853
# 8474652              0.010204              0.092414             0.033853
# 8474653              0.091837              0.092414             0.033853
# 8474654              0.010204              0.092414             0.033853
# 8474655              0.020408              0.092414             0.033853
# 8474656              0.000000              0.092414             0.033853
# 8474657              0.091837              0.092414             0.033853
# 8474658              0.010204              0.092414             0.033853
# 8474659              0.122449              0.092414             0.033853
# 8474660              0.010204              0.092414             0.033853
#
# [8474661 rows x 3 columns]

# %% [markdown]
# ### 모든 데이터 통합 완료 & 사용할 attribute 선정

# %%
train_df.columns
# Out:
# Index(['user_id', 'order_id', 'product_id', 'products', 'eval_set',
#        'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order', 'categorized_hour_0', 'categorized_hour_1',
#        'categorized_hour_2', 'categorized_hour_3', 'product_name', 'aisle_id',
#        'department_id', 'product_orders', 'product_reorders',
#        'product_reorder_rate', 'norm_product_reorders', 'user_total_products',
#        'user_unique_products', 'ordered_products_set',
#        'user_avg_orders_period', 'user_total_orders', 'user_avg_cart',
#        'days_since_ratio', 'UP_orders', 'UP_last_order_id',
#        'UP_sum_pos_in_cart', 'UP_orders_ratio', 'UP_avg_pos_in_cart',
#        'UP_reorder_rate', 'UP_orders_since_last', 'UP_delta_hour_vs_last'],
#       dtype='object')

# %%
features = [
    # order information
    'categorized_hour_0', 'categorized_hour_1', 'categorized_hour_2', 'categorized_hour_3',
    'days_since_prior_order', 'days_since_ratio',
    # product information
    'aisle_id', 'department_id', 'product_orders', 'product_reorders', 'product_reorder_rate', 
    # user information
    'user_total_products', 'user_unique_products', 'user_avg_orders_period', 'user_total_orders', 'user_avg_cart', 
    # userXproduct information
    'UP_orders', 'UP_orders_ratio', 'UP_avg_pos_in_cart', 'UP_reorder_rate', 'UP_orders_since_last', 'UP_delta_hour_vs_last'
]

# %%
train_X = train_df[features]
train_y = train_df['products']

# %% [markdown]
# # 6. Test Data Generation

# %%
test_df = frame_test.copy()
test_df = test_df.merge(orders, how='left', on=['user_id','order_id'])
test_df = test_df.merge(Products, how='left', on='product_id')
test_df = test_df.merge(Users, how='left', on='user_id')

test_df['days_since_ratio'] = test_df.days_since_prior_order / test_df.user_avg_orders_period

test_df['user_product'] = test_df.user_id * 100000 + test_df.product_id
test_df = test_df.merge(userXproduct, how='left', on='user_product')
test_df.drop(['user_product'], axis=1, inplace=True)

test_df['UP_orders_ratio'] = test_df.UP_orders / test_df.user_total_orders
test_df['UP_avg_pos_in_cart'] = test_df.UP_sum_pos_in_cart / test_df.UP_orders
test_df['UP_reorder_rate'] = test_df.UP_orders / test_df.user_total_orders
test_df['UP_orders_since_last'] = test_df.user_total_orders - test_df.UP_last_order_id.map(orders.order_number)
test_df['UP_delta_hour_vs_last'] = abs(test_df.order_hour_of_day - test_df.UP_last_order_id.map(orders.order_hour_of_day)).map(lambda x: min(x, 24-x))

# %% [markdown]
# # normalization test_df['UP_orders_since_last']

# %%
test_df['UP_orders_since_last'] =(test_df['UP_orders_since_last']-train_mean)/(train_std)

test_df['UP_orders_since_last']
# Out:
# 0          0.010204
# 1          0.061224
# 2          0.030612
# 3          0.000000
# 4          0.051020
# 5          0.102041
# 6          0.020408
# 7          0.040816
# 8          0.091837
# 9          0.000000
# 10         0.000000
# 11         0.071429
# 12         0.051020
# 13         0.102041
# 14         0.030612
# 15         0.000000
# 16         0.112245
# 17         0.051020
# 18         0.081633
# 19         0.010204
# 20         0.040816
# 21         0.071429
# 22         0.102041
# 23         0.071429
# 24         0.051020
# 25         0.091837
# 26         0.102041
# 27         0.071429
# 28         0.000000
# 29         0.000000
#              ...
# 4833262    0.061224
# 4833263    0.091837
# 4833264    0.000000
# 4833265    0.030612
# 4833266    0.000000
# 4833267    0.020408
# 4833268    0.040816
# 4833269    0.102041
# 4833270    0.051020
# 4833271    0.000000
# 4833272    0.000000
# 4833273    0.142857
# 4833274    0.183673
# 4833275    0.204082
# 4833276    0.387755
# 4833277    0.306122
# 4833278    0.377551
# 4833279    0.397959
# 4833280    0.112245
# 4833281    0.020408
# 4833282    0.091837
# 4833283    0.010204
# 4833284    0.122449
# 4833285    0.163265
# 4833286    0.234694
# 4833287    0.061224
# 4833288    0.030612
# 4833289    0.061224
# 4833290    0.071429
# 4833291    0.081633
# Name: UP_orders_since_last, Length: 4833292, dtype: float64

# %%
test_X = test_df[features]

# %% [markdown]
# # 7. Learning & Prediction

# %%
import lightgbm as lgb

# %%
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': {'binary_logloss'},
    'num_leaves': 96,
    'max_depth': 10,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.95,
    'bagging_freq': 5
}
ROUNDS = 100

# %% [markdown]
# ### Learning

# %%
train_X_ds = lgb.Dataset(train_X, label=train_y, categorical_feature=['aisle_id','department_id'])

# %%
bst = lgb.train(params, train_X_ds, ROUNDS)

# %%
# %matplotlib inline 
lgb.plot_importance(bst, figsize=(9,20))

# %% [markdown]
# ### Prediction

# %%
result = bst.predict(test_X)

# %%
result = pd.concat([frame_test,pd.DataFrame(result, columns=['predict'])], axis=1)

# %%
result.head()
# Out:
#    user_id  order_id  product_id   predict
# 0        3   2774568       17668  0.364363
# 1        3   2774568       44683  0.070070
# 2        3   2774568       48523  0.083777
# 3        3   2774568       21903  0.636941
# 4        3   2774568       14992  0.084690

# %%
result
# Out:
#          user_id  order_id  product_id   predict
# 0              3   2774568       17668  0.364363
# 1              3   2774568       44683  0.070070
# 2              3   2774568       48523  0.083777
# 3              3   2774568       21903  0.636941
# 4              3   2774568       14992  0.084690
# 5              3   2774568       21137  0.065396
# 6              3   2774568       32402  0.192033
# 7              3   2774568       22035  0.153873
# 8              3   2774568       49683  0.044500
# 9              3   2774568       39190  0.752548
# 10             3   2774568       47766  0.706004
# 11             3   2774568       42265  0.058657
# 12             3   2774568        1819  0.097786
# 13             3   2774568       40604  0.035392
# 14             3   2774568       16797  0.164554
# 15             3   2774568       18599  0.324695
# 16             3   2774568       15143  0.021073
# 17             3   2774568        9387  0.140200
# 18             3   2774568       12845  0.028533
# 19             3   2774568       43961  0.314142
# 20             3   2774568       42557  0.052836
# 21             3   2774568       18370  0.043341
# 22             3   2774568       38596  0.024420
# 23             3   2774568       16965  0.057710
# 24             3   2774568       24010  0.080375
# 25             3   2774568        7503  0.030642
# 26             3   2774568        8021  0.039315
# 27             3   2774568       28373  0.068527
# 28             3   2774568       23650  0.397347
# 29             3   2774568       24810  0.282039
# ...          ...       ...         ...       ...
# 4833262   206208    803273       47008  0.017465
# 4833263   206208    803273       36772  0.038184
# 4833264   206208    803273       34213  0.742819
# 4833265   206208    803273        1463  0.198281
# 4833266   206208    803273       43961  0.204539
# 4833267   206208    803273       14778  0.240739
# 4833268   206208    803273       18880  0.026456
# 4833269   206208    803273       24009  0.018007
# 4833270   206208    803273       17355  0.018058
# 4833271   206208    803273       45007  0.166217
# 4833272   206208    803273        7632  0.016563
# 4833273   206208    803273       13775  0.005518
# 4833274   206208    803273       49621  0.013149
# 4833275   206208    803273       21461  0.011059
# 4833276   206208    803273       27608  0.008905
# 4833277   206208    803273       23516  0.009040
# 4833278   206208    803273       16349  0.011623
# 4833279   206208    803273       12252  0.006007
# 4833280   206208    803273       43999  0.024839
# 4833281   206208    803273       31717  0.240953
# 4833282   206208    803273       22504  0.033153
# 4833283   206208    803273       34282  0.067321
# 4833284   206208    803273       21996  0.018634
# 4833285   206208    803273        8174  0.019460
# 4833286   206208    803273       31215  0.020837
# 4833287   206208    803273       44532  0.017469
# 4833288   206208    803273       46069  0.151115
# 4833289   206208    803273       12791  0.022701
# 4833290   206208    803273       14332  0.015320
# 4833291   206208    803273        4605  0.040070
#
# [4833292 rows x 4 columns]

# %% [markdown]
# # 8. Prediction Probability 기반 최종 products list 생성

# %%
sorted_result = result.sort_values(['user_id', 'predict'], ascending=[True,False])

# %%
sorted_result.head()
# Out:
#     user_id  order_id  product_id   predict
# 9         3   2774568       39190  0.752548
# 10        3   2774568       47766  0.706004
# 3         3   2774568       21903  0.636941
# 28        3   2774568       23650  0.397347
# 0         3   2774568       17668  0.364363

# %%
sorted_result.reset_index(inplace=True)
sorted_result.drop(['index'], axis=1, inplace=True)
sorted_result.head()
# Out:
#    user_id  order_id  product_id   predict
# 0        3   2774568       39190  0.752548
# 1        3   2774568       47766  0.706004
# 2        3   2774568       21903  0.636941
# 3        3   2774568       23650  0.397347
# 4        3   2774568       17668  0.364363

# %%
sorted_result
# Out:
#          user_id  order_id  product_id   predict
# 0              3   2774568       39190  0.752548
# 1              3   2774568       47766  0.706004
# 2              3   2774568       21903  0.636941
# 3              3   2774568       23650  0.397347
# 4              3   2774568       17668  0.364363
# 5              3   2774568       18599  0.324695
# 6              3   2774568       43961  0.314142
# 7              3   2774568       24810  0.282039
# 8              3   2774568       32402  0.192033
# 9              3   2774568       16797  0.164554
# 10             3   2774568       22035  0.153873
# 11             3   2774568        9387  0.140200
# 12             3   2774568        1819  0.097786
# 13             3   2774568       14992  0.084690
# 14             3   2774568       48523  0.083777
# 15             3   2774568       24010  0.080375
# 16             3   2774568       44683  0.070070
# 17             3   2774568       28373  0.068527
# 18             3   2774568       21137  0.065396
# 19             3   2774568        1005  0.061736
# 20             3   2774568       42265  0.058657
# 21             3   2774568       16965  0.057710
# 22             3   2774568       42557  0.052836
# 23             3   2774568       49683  0.044500
# 24             3   2774568       18370  0.043341
# 25             3   2774568        8021  0.039315
# 26             3   2774568       40604  0.035392
# 27             3   2774568        7503  0.030642
# 28             3   2774568       12845  0.028533
# 29             3   2774568       38596  0.024420
# ...          ...       ...         ...       ...
# 4833262   206208    803273       31801  0.006719
# 4833263   206208    803273       36651  0.006706
# 4833264   206208    803273       49247  0.006652
# 4833265   206208    803273       16490  0.006593
# 4833266   206208    803273       26177  0.006585
# 4833267   206208    803273        7228  0.006268
# 4833268   206208    803273       46271  0.006181
# 4833269   206208    803273       42891  0.006145
# 4833270   206208    803273       29474  0.006044
# 4833271   206208    803273       12252  0.006007
# 4833272   206208    803273       49385  0.005973
# 4833273   206208    803273       31287  0.005848
# 4833274   206208    803273       35217  0.005840
# 4833275   206208    803273       38250  0.005723
# 4833276   206208    803273       42296  0.005675
# 4833277   206208    803273        5133  0.005611
# 4833278   206208    803273       13775  0.005518
# 4833279   206208    803273       46868  0.005459
# 4833280   206208    803273       41055  0.005280
# 4833281   206208    803273       27714  0.005213
# 4833282   206208    803273          95  0.005195
# 4833283   206208    803273       29079  0.005109
# 4833284   206208    803273         165  0.004924
# 4833285   206208    803273       22417  0.004615
# 4833286   206208    803273       25447  0.004572
# 4833287   206208    803273        4376  0.004148
# 4833288   206208    803273       47752  0.003638
# 4833289   206208    803273        8203  0.003549
# 4833290   206208    803273       15975  0.003218
# 4833291   206208    803273       28741  0.003104
#
# [4833292 rows x 4 columns]

# %%
ordered_products = sorted_result.groupby(['user_id', 'order_id'])['product_id'].apply(list)
ordered_products
# Out:
# user_id  order_id
# 3        2774568     [39190, 47766, 21903, 23650, 17668, 18599, 439...
# 4        329954      [26576, 21573, 25623, 35469, 25146, 19057, 376...
# 6        1528013     [21903, 38293, 8424, 27521, 45007, 25659, 4867...
# 11       1376945     [8309, 27959, 14947, 13176, 33572, 28465, 3465...
# 12       1356845     [13176, 7076, 10863, 14992, 11520, 28134, 2161...
# 15       2161313     [10441, 196, 12427, 14715, 27839, 11266, 37710...
# 16       1416320     [24852, 21903, 21137, 5134, 17948, 41950, 2456...
# 19       1735923     [17008, 34690, 31487, 35123, 15131, 196, 12108...
# 20       1980631       [13575, 22362, 9387, 46061, 13914, 6184, 41400]
# 22       139655      [27845, 17794, 22935, 35221, 13176, 22963, 249...
# 25       1411408     [22008, 26452, 43758, 10096, 37119, 27521, 121...
# 26       2940603     [19894, 44632, 30592, 31615, 14947, 10339, 185...
# 28       1192143     [24852, 47626, 35510, 27307, 49683, 8424, 4195...
# 31       280888      [32566, 19213, 41406, 12440, 13966, 35413, 459...
# 32       3202221     [24852, 9637, 4793, 49215, 11130, 21137, 17630...
# 33       3222866     [33198, 32912, 8501, 37131, 7969, 15718, 35921...
# 35       707453      [4942, 48230, 24852, 694, 18150, 32030, 28156,...
# 36       1320132     [44632, 22328, 12145, 47977, 39184, 33153, 442...
# 39       882556      [48679, 25890, 24852, 7371, 30962, 8424, 5450,...
# 40       2431024     [24799, 13176, 34217, 39928, 6975, 5699, 27555...
# 45       2827745     [17924, 47660, 43279, 27959, 20770, 20754, 409...
# 51       2174416     [15712, 36929, 18798, 10017, 13176, 40604, 476...
# 54       1325316     [26165, 47626, 24964, 24852, 38231, 47766, 120...
# 57       320326      [42828, 24852, 45646, 41896, 4302, 35163, 8193...
# 58       2128599     [14818, 622, 7628, 24703, 49227, 36750, 33219,...
# 60       1099519     [13176, 22035, 28058, 26351, 24838, 5428, 1679...
# 61       144494      [14947, 46260, 39108, 16959, 23106, 23431, 394...
# 68       3024191     [27521, 30233, 22260, 42450, 18362, 7948, 2638...
# 69       2817181     [18828, 41618, 19677, 28058, 1377, 22559, 4786...
# 73       2883656     [24852, 21497, 8193, 19660, 21137, 44661, 4039...
#                                            ...
# 206122   1968103     [2086, 4357, 49683, 40604, 3479, 41950, 8518, ...
# 206127   3094655     [37132, 31102, 32745, 21086, 45531, 49198, 445...
# 206131   2964171     [12564, 42450, 19660, 35584, 38580, 16223, 131...
# 206135   1522572     [24852, 47766, 27966, 21903, 3952, 43122, 1690...
# 206138   544857      [16797, 12341, 29223, 32478, 38768, 13176, 330...
# 206142   1421496     [11365, 12341, 37687, 21903, 39534, 14715, 179...
# 206143   765758      [38563, 18212, 24852, 536, 24954, 22124, 13203...
# 206147   1772796     [42445, 21903, 29447, 27845, 39408, 22825, 312...
# 206152   3177219     [30233, 21616, 8479, 35951, 19008, 34969, 3940...
# 206160   2380361     [12919, 30233, 1804, 432, 7693, 42719, 21334, ...
# 206161   928262      [39180, 21137, 11777, 10912, 36961, 1215, 2063...
# 206163   1722401        [21195, 48812, 5258, 19660, 34551, 7862, 6324]
# 206166   1945444     [22839, 22212, 14260, 6873, 44233, 5876, 33540...
# 206168   2000023     [25466, 27730, 3283, 38456, 47029, 48726, 2060...
# 206173   3151043     [15003, 5785, 29615, 9477, 40332, 49326, 12276...
# 206179   2900626     [27307, 49007, 36316, 26528, 32842, 38726, 171...
# 206180   2633505     [24852, 39332, 7280, 2295, 43726, 26604, 45066...
# 206182   1836967     [23909, 10279, 25570, 15324, 10890, 25830, 270...
# 206183   2799087     [24852, 27966, 45007, 43961, 47209, 45603, 211...
# 206187   2762353     [45842, 21405, 8555, 34429, 5652, 8277, 21982,...
# 206189   959487      [9623, 18205, 15902, 47209, 8021, 36724, 34991...
# 206192   701105      [24852, 42943, 17341, 8247, 13951, 21573, 2161...
# 206194   64567       [24852, 43740, 28204, 32740, 21709, 21903, 151...
# 206197   1564541     [21903, 17948, 30450, 48023, 42719, 29195, 213...
# 206201   309211      [23909, 21267, 34024, 41276, 38737, 294, 5782,...
# 206202   2728930     [24852, 2693, 17038, 21709, 432, 38837, 12919,...
# 206204   350108      [43961, 30561, 15649, 5646, 33754, 21137, 4907...
# 206206   1043943     [38530, 11520, 23029, 27086, 47011, 13045, 426...
# 206207   2821651     [44632, 13176, 36011, 39180, 33787, 27966, 278...
# 206208   803273      [34213, 13176, 21137, 27845, 33000, 23579, 314...
# Name: product_id, Length: 75000, dtype: object

# %%
d = dict()
for (uid, oid), row in ordered_products.iteritems():
    avg_cart = Users[Users.user_id == uid]['user_avg_cart'].values[0]
    
    row = row[:int(round(avg_cart))]
    
    for prod in row:    
        try:
            d[oid] += ' ' + str(prod)
        except:
            d[oid] = str(prod)

# %%
output = pd.DataFrame.from_dict(d, orient='index')
output.reset_index(inplace=True)
output.columns = ['order_id', 'products']
output.head()
# Out:
#    order_id                                           products
# 0   2774568          39190 47766 21903 23650 17668 18599 43961
# 1    329954                            26576 21573 25623 35469
# 2   1528013                       21903 38293 8424 27521 45007
# 3   1376945  8309 27959 14947 13176 33572 28465 34658 44632...
# 4   1356845  13176 7076 10863 14992 11520 28134 21616 22959...

# %%
output.to_csv('LightGBM-improving_userXproduct.csv', index=False)
