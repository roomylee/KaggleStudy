# %% [markdown]
# # LightGBM 기반 UP(userXproduct) feature 추가 - 에러 수정 (LB 0.3715530)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 0. Introduction of Data

# %%
products = pd.read_csv("../data/products.csv")
aisles = pd.read_csv("../data/aisles.csv")
departments = pd.read_csv("../data/departments.csv")
orders = pd.read_csv("../data/orders.csv")
prior = pd.read_csv("../data/order_products__prior.csv")
train = pd.read_csv("../data/order_products__train.csv")
frame_train = pd.read_csv("../data/frame_train.csv")
frame_test = pd.read_csv("../data/frame_test.csv")
userXproduct = pd.read_csv("../data/userXproduct.csv")

# %% [markdown]
# ### orders.csv

# %%
print("Size of orders : ", len(orders))
orders.head()
# Out:
# Size of orders :  3421083
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ### order_products_prior.csv

# %%
print("Size of prior : ", len(prior))
prior.head()
# Out:
# Size of prior :  32434489
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %% [markdown]
# ### products.csv

# %%
print("Size of Products : ", len(products))
products.head()
# Out:
# Size of Products :  49688
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %% [markdown]
# ### frame_train.csv

# %%
print("Size of frame of train : ", len(frame_train))
frame_train.head()
# Out:
# Size of frame of train :  8474661
#    user_id  order_id  product_id  products
# 0        1   1187899       17122         0
# 1        1   1187899         196         1
# 2        1   1187899       26405         1
# 3        1   1187899       46149         1
# 4        1   1187899       14084         0

# %% [markdown]
# # 1. orders Information - categorization of order hour

# %%
orders.set_index('order_id', inplace=True, drop=False)

# %%
orders['categorized_order_hour_of_day'] = 0
orders.loc[orders['order_hour_of_day']>=9,'categorized_order_hour_of_day'] = 1
orders.loc[orders['order_hour_of_day']>=13,'categorized_order_hour_of_day'] = 2
orders.loc[orders['order_hour_of_day']>=19,'categorized_order_hour_of_day'] = 3
orders.head()
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# order_id
# 2539329    2539329        1    prior             1          2
# 2398795    2398795        1    prior             2          3
# 473747      473747        1    prior             3          3
# 2254736    2254736        1    prior             4          4
# 431534      431534        1    prior             5          4
#
#           order_hour_of_day  days_since_prior_order  \
# order_id
# 2539329                   8                     NaN
# 2398795                   7                    15.0
# 473747                   12                    21.0
# 2254736                   7                    29.0
# 431534                   15                    28.0
#
#           categorized_order_hour_of_day
# order_id
# 2539329                               0
# 2398795                               0
# 473747                                1
# 2254736                               0
# 431534                                2

# %%
orders = orders.join(pd.get_dummies(orders['categorized_order_hour_of_day'], prefix='categorized_hour'))
orders.drop(['categorized_order_hour_of_day'], axis=1, inplace=True)

# %%
orders.head(20)
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# order_id
# 2539329    2539329        1    prior             1          2
# 2398795    2398795        1    prior             2          3
# 473747      473747        1    prior             3          3
# 2254736    2254736        1    prior             4          4
# 431534      431534        1    prior             5          4
# 3367565    3367565        1    prior             6          2
# 550135      550135        1    prior             7          1
# 3108588    3108588        1    prior             8          1
# 2295261    2295261        1    prior             9          1
# 2550362    2550362        1    prior            10          4
# 1187899    1187899        1    train            11          4
# 2168274    2168274        2    prior             1          2
# 1501582    1501582        2    prior             2          5
# 1901567    1901567        2    prior             3          1
# 738281      738281        2    prior             4          2
# 1673511    1673511        2    prior             5          3
# 1199898    1199898        2    prior             6          2
# 3194192    3194192        2    prior             7          2
# 788338      788338        2    prior             8          1
# 1718559    1718559        2    prior             9          2
#
#           order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# order_id
# 2539329                   8                     NaN                   1
# 2398795                   7                    15.0                   1
# 473747                   12                    21.0                   0
# 2254736                   7                    29.0                   1
# 431534                   15                    28.0                   0
# 3367565                   7                    19.0                   1
# 550135                    9                    20.0                   0
# 3108588                  14                    14.0                   0
# 2295261                  16                     0.0                   0
# 2550362                   8                    30.0                   1
# 1187899                   8                    14.0                   1
# 2168274                  11                     NaN                   0
# 1501582                  10                    10.0                   0
# 1901567                  10                     3.0                   0
# 738281                   10                     8.0                   0
# 1673511                  11                     8.0                   0
# 1199898                   9                    13.0                   0
# 3194192                  12                    14.0                   0
# 788338                   15                    27.0                   0
# 1718559                   9                     8.0                   0
#
#           categorized_hour_1  categorized_hour_2  categorized_hour_3
# order_id
# 2539329                    0                   0                   0
# 2398795                    0                   0                   0
# 473747                     1                   0                   0
# 2254736                    0                   0                   0
# 431534                     0                   1                   0
# 3367565                    0                   0                   0
# 550135                     1                   0                   0
# 3108588                    0                   1                   0
# 2295261                    0                   1                   0
# 2550362                    0                   0                   0
# 1187899                    0                   0                   0
# 2168274                    1                   0                   0
# 1501582                    1                   0                   0
# 1901567                    1                   0                   0
# 738281                     1                   0                   0
# 1673511                    1                   0                   0
# 1199898                    1                   0                   0
# 3194192                    1                   0                   0
# 788338                     0                   1                   0
# 1718559                    1                   0                   0

# %% [markdown]
# ## 1-1. User's Frequent Order Time
# - User의 주문시간의 최빈시간 추가
# - Order의 경우와 마찬가지로 One-Hot Incoding

# %%
user_frequent_time = pd.DataFrame()
user_frequent_time['0_count'] = orders.groupby('user_id')['categorized_hour_0'].sum()
user_frequent_time['1_count'] = orders.groupby('user_id')['categorized_hour_1'].sum()
user_frequent_time['2_count'] = orders.groupby('user_id')['categorized_hour_2'].sum()
user_frequent_time['3_count'] = orders.groupby('user_id')['categorized_hour_3'].sum()
user_frequent_time['user_id'] = user_frequent_time.index
user_frequent_time['max_count'] = user_frequent_time[['0_count','1_count','2_count','3_count']].max(axis=1)

user_frequent_time['0_count'] = (user_frequent_time['0_count'] == user_frequent_time['max_count'])
user_frequent_time['1_count'] = (user_frequent_time['1_count'] == user_frequent_time['max_count'])
user_frequent_time['2_count'] = (user_frequent_time['2_count'] == user_frequent_time['max_count'])
user_frequent_time['3_count'] = (user_frequent_time['3_count'] == user_frequent_time['max_count'])

user_frequent_time.drop(['max_count'], axis = 1, inplace = True)
user_frequent_time.head()
# Out:
#          0_count  1_count  2_count  3_count  user_id
# user_id
# 1           True    False    False    False        1
# 2          False     True    False    False        2
# 3          False    False     True    False        3
# 4          False     True     True    False        4
# 5          False    False     True    False        5

# %% [markdown]
# # 2. Integrate Products Information
# * products와 prior에서 얻을 수 있는 제품 관련 정보를 통합
# * 기존의 attribute인 product_id, product_name, aisle_id, department_id
# * 여기에 prior에서 얻을 수 있는 해당 제품에 판매에 관련된 attribute를 추가
# * 총주문량(total_orders), 총재주문량(total_reorders), 재주문율(reorder_rate)을 추가함

# %%
productsXprior = pd.DataFrame()
productsXprior['product_id'] = prior.groupby(prior.product_id).size().index
productsXprior['product_orders'] = prior.groupby(prior.product_id).size().values
productsXprior['product_reorders'] = prior['reordered'].groupby(prior.product_id).sum().values
productsXprior['product_reorder_rate'] = (productsXprior.product_reorders / productsXprior.product_orders)
print("Size of productsXprior : ", len(productsXprior))
productsXprior.head()
# Out:
# Size of productsXprior :  49677
#    product_id  product_orders  product_reorders  product_reorder_rate
# 0           1            1852              1136              0.613391
# 1           2              90                12              0.133333
# 2           3             277               203              0.732852
# 3           4             329               147              0.446809
# 4           5              15                 9              0.600000

# %%
Products = products.merge(productsXprior, on='product_id', how='outer')
print("Size of Products : ", len(Products))
Products.head()
# Out:
# Size of Products :  49688
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  product_orders  product_reorders  product_reorder_rate
# 0             19          1852.0            1136.0              0.613391
# 1             13            90.0              12.0              0.133333
# 2              7           277.0             203.0              0.732852
# 3              1           329.0             147.0              0.446809
# 4             13            15.0               9.0              0.600000

# %%
Products[Products.isnull().any(axis=1)]
# Out:
#        product_id                                       product_name  \
# 3629         3630                        Protein Granola Apple Crisp
# 3717         3718                   Wasabi Cheddar Spreadable Cheese
# 7044         7045             Unpeeled Apricot Halves in Heavy Syrup
# 25382       25383                                 Chocolate Go Bites
# 27498       27499                  Non-Dairy Coconut Seven Layer Bar
# 36232       36233                            Water With Electrolytes
# 37702       37703  Ultra Sun Blossom Liquid 90 loads Fabric Enhan...
# 43724       43725                               Sweetart Jelly Beans
# 45970       45971                         12 Inch Taper Candle White
# 46624       46625    Single Barrel Kentucky Straight Bourbon Whiskey
# 49539       49540                            Pure Squeezed  Lemonade
#
#        aisle_id  department_id  product_orders  product_reorders  \
# 3629         57             14             NaN               NaN
# 3717         21             16             NaN               NaN
# 7044         88             13             NaN               NaN
# 25382        61             19             NaN               NaN
# 27498       100             21             NaN               NaN
# 36232       100             21             NaN               NaN
# 37702        75             17             NaN               NaN
# 43724       100             21             NaN               NaN
# 45970       101             17             NaN               NaN
# 46624        31              7             NaN               NaN
# 49539        31              7             NaN               NaN
#
#        product_reorder_rate
# 3629                    NaN
# 3717                    NaN
# 7044                    NaN
# 25382                   NaN
# 27498                   NaN
# 36232                   NaN
# 37702                   NaN
# 43724                   NaN
# 45970                   NaN
# 46624                   NaN
# 49539                   NaN

# %%
Products = Products.replace(np.NaN, 0)
print("Size of Products : ", len(Products))
Products.head()
# Out:
# Size of Products :  49688
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  product_orders  product_reorders  product_reorder_rate
# 0             19          1852.0            1136.0              0.613391
# 1             13            90.0              12.0              0.133333
# 2              7           277.0             203.0              0.732852
# 3              1           329.0             147.0              0.446809
# 4             13            15.0               9.0              0.600000

# %% [markdown]
# # 3. Integrate_Users_Information
# * prior와 orders를 통합(priorXorders)하여 user_id, order_id, product_id를 하나로 모음.
# * priorXorders를 기반으로 하여 유저 정보를 담고 있는 Users를 생성.

# %%
priorXorders = prior.merge(orders, on='order_id')
print("Size of Prior : ", len(priorXorders))
priorXorders.head()
# Out:
# Size of Prior :  32434489
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0
#
#    categorized_hour_0  categorized_hour_1  categorized_hour_2  \
# 0                   0                   1                   0
# 1                   0                   1                   0
# 2                   0                   1                   0
# 3                   0                   1                   0
# 4                   0                   1                   0
#
#    categorized_hour_3
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
user_orders = pd.DataFrame()
user_orders['user_avg_orders_period'] = orders.groupby('user_id')['days_since_prior_order'].mean()
user_orders['user_total_orders'] = orders.groupby('user_id').size()

user_orders['user_id'] = user_orders.index
user_orders.index.name = None

print("Size of user_orders : ", len(user_orders))
user_orders.head()
# Out:
# Size of user_orders :  206209
#    user_avg_orders_period  user_total_orders  user_id
# 1               19.000000                 11        1
# 2               16.285714                 15        2
# 3               12.000000                 13        3
# 4               17.000000                  6        4
# 5               11.500000                  5        5

# %%
user_prior = pd.DataFrame()
user_prior['user_total_products'] = priorXorders.groupby('user_id').size()
user_prior['ordered_products_set'] = priorXorders.groupby('user_id')['product_id'].apply(set)
user_prior['user_unique_products'] = (user_prior.ordered_products_set.map(len))
user_prior = user_prior[['user_total_products', 'user_unique_products', 'ordered_products_set']]

user_prior['user_id'] = user_prior.index
user_prior.index.name = None

print("Size of user_prior : ", len(user_prior))
user_prior.head()
# Out:
# Size of user_prior :  206209
#    user_total_products  user_unique_products  \
# 1                   59                    18
# 2                  195                   102
# 3                   88                    33
# 4                   18                    17
# 5                   37                    23
#
#                                 ordered_products_set  user_id
# 1  {17122, 196, 26405, 46149, 14084, 13032, 26088...        1
# 2  {45066, 2573, 18961, 23, 32792, 1559, 22559, 1...        2
# 3  {17668, 44683, 48523, 21903, 14992, 21137, 324...        3
# 4  {21573, 42329, 17769, 35469, 37646, 1200, 1905...        4
# 5  {11777, 40706, 28289, 48775, 20754, 6808, 1398...        5

# %%
Users = user_prior.merge(user_orders, on='user_id')
print("Size of users : ", len(Users))
Users.head()
# Out:
# Size of users :  206209
#    user_total_products  user_unique_products  \
# 0                   59                    18
# 1                  195                   102
# 2                   88                    33
# 3                   18                    17
# 4                   37                    23
#
#                                 ordered_products_set  user_id  \
# 0  {17122, 196, 26405, 46149, 14084, 13032, 26088...        1
# 1  {45066, 2573, 18961, 23, 32792, 1559, 22559, 1...        2
# 2  {17668, 44683, 48523, 21903, 14992, 21137, 324...        3
# 3  {21573, 42329, 17769, 35469, 37646, 1200, 1905...        4
# 4  {11777, 40706, 28289, 48775, 20754, 6808, 1398...        5
#
#    user_avg_orders_period  user_total_orders
# 0               19.000000                 11
# 1               16.285714                 15
# 2               12.000000                 13
# 3               17.000000                  6
# 4               11.500000                  5

# %%
Users['user_avg_cart'] = (Users.user_total_products / (Users.user_total_orders - 1))
print("Size of users : ", len(Users))
Users.head()
# Out:
# Size of users :  206209
#    user_total_products  user_unique_products  \
# 0                   59                    18
# 1                  195                   102
# 2                   88                    33
# 3                   18                    17
# 4                   37                    23
#
#                                 ordered_products_set  user_id  \
# 0  {17122, 196, 26405, 46149, 14084, 13032, 26088...        1
# 1  {45066, 2573, 18961, 23, 32792, 1559, 22559, 1...        2
# 2  {17668, 44683, 48523, 21903, 14992, 21137, 324...        3
# 3  {21573, 42329, 17769, 35469, 37646, 1200, 1905...        4
# 4  {11777, 40706, 28289, 48775, 20754, 6808, 1398...        5
#
#    user_avg_orders_period  user_total_orders  user_avg_cart
# 0               19.000000                 11       5.900000
# 1               16.285714                 15      13.928571
# 2               12.000000                 13       7.333333
# 3               17.000000                  6       3.600000
# 4               11.500000                  5       9.250000

# %% [markdown]
# # 4. UP(userXproduct) Information

# %%
userXproduct.columns = ['user_product','UP_orders','UP_last_order_id','UP_sum_pos_in_cart']
print('Size of user X product', len(userXproduct))
userXproduct.head()
# Out:
# Size of user X product 13307953
#    user_product  UP_orders  UP_last_order_id  UP_sum_pos_in_cart
# 0   14126415872          5            843810                  63
# 1   20535312385          1           2699553                   9
# 2    1375731717          7           2844957                  51
# 3    8959033352          4           1924807                  57
# 4    7342828204          3            723315                  13

# %% [markdown]
# # 5. Train Data Generation
# * ### 미리 만들어 둔 frame_train을 기반으로 위의 orders, Products, Users 정보를 통합시켜 train data를 만듬.
# * order_prior, order_train은 학습데이터로 포함 X, order_test가 없기 때문에 test데이터에 해당 attribute를 포함시킬 수 없음.

# %%
train_df = frame_train.copy()
train_df.set_index(['user_id','order_id','product_id']).head(10)
# Out:
#                              products
# user_id order_id product_id
# 1       1187899  17122              0
#                  196                1
#                  26405              1
#                  46149              1
#                  14084              0
#                  13032              1
#                  26088              1
#                  39657              1
#                  12427              0
#                  25133              1

# %% [markdown]
# ### 1) orders Information 통합

# %%
train_df = train_df.merge(orders, how='left', on=['user_id','order_id'])
train_df.head()
# Out:
#    user_id  order_id  product_id  products eval_set  order_number  order_dow  \
# 0        1   1187899       17122         0    train            11          4
# 1        1   1187899         196         1    train            11          4
# 2        1   1187899       26405         1    train            11          4
# 3        1   1187899       46149         1    train            11          4
# 4        1   1187899       14084         0    train            11          4
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# 0                  8                    14.0                   1
# 1                  8                    14.0                   1
# 2                  8                    14.0                   1
# 3                  8                    14.0                   1
# 4                  8                    14.0                   1
#
#    categorized_hour_1  categorized_hour_2  categorized_hour_3
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0

# %% [markdown]
# ### 2) Products Information 통합

# %%
train_df = train_df.merge(Products, how='left', on='product_id')
train_df.head()
# Out:
#    user_id  order_id  product_id  products eval_set  order_number  order_dow  \
# 0        1   1187899       17122         0    train            11          4
# 1        1   1187899         196         1    train            11          4
# 2        1   1187899       26405         1    train            11          4
# 3        1   1187899       46149         1    train            11          4
# 4        1   1187899       14084         0    train            11          4
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# 0                  8                    14.0                   1
# 1                  8                    14.0                   1
# 2                  8                    14.0                   1
# 3                  8                    14.0                   1
# 4                  8                    14.0                   1
#
#    categorized_hour_1  categorized_hour_2  categorized_hour_3  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#                               product_name  aisle_id  department_id  \
# 0                        Honeycrisp Apples        24              4
# 1                                     Soda        77              7
# 2         XL Pick-A-Size Paper Towel Rolls        54             17
# 3                        Zero Calorie Cola        77              7
# 4  Organic Unsweetened Vanilla Almond Milk        91             16
#
#    product_orders  product_reorders  product_reorder_rate
# 0         13880.0            9377.0              0.675576
# 1         35791.0           27791.0              0.776480
# 2          1214.0             536.0              0.441516
# 3          8558.0            6953.0              0.812456
# 4         15935.0           12923.0              0.810982

# %% [markdown]
# ### 3) Users Information 통합

# %%
train_df = train_df.merge(Users, how='left', on='user_id')
train_df.head()
# Out:
#    user_id  order_id  product_id  products eval_set  order_number  order_dow  \
# 0        1   1187899       17122         0    train            11          4
# 1        1   1187899         196         1    train            11          4
# 2        1   1187899       26405         1    train            11          4
# 3        1   1187899       46149         1    train            11          4
# 4        1   1187899       14084         0    train            11          4
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# 0                  8                    14.0                   1
# 1                  8                    14.0                   1
# 2                  8                    14.0                   1
# 3                  8                    14.0                   1
# 4                  8                    14.0                   1
#
#        ...        department_id  product_orders  product_reorders  \
# 0      ...                    4         13880.0            9377.0
# 1      ...                    7         35791.0           27791.0
# 2      ...                   17          1214.0             536.0
# 3      ...                    7          8558.0            6953.0
# 4      ...                   16         15935.0           12923.0
#
#   product_reorder_rate  user_total_products  user_unique_products  \
# 0             0.675576                   59                    18
# 1             0.776480                   59                    18
# 2             0.441516                   59                    18
# 3             0.812456                   59                    18
# 4             0.810982                   59                    18
#
#                                 ordered_products_set  user_avg_orders_period  \
# 0  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
# 1  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
# 2  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
# 3  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
# 4  {17122, 196, 26405, 46149, 14084, 13032, 26088...                    19.0
#
#    user_total_orders  user_avg_cart
# 0                 11            5.9
# 1                 11            5.9
# 2                 11            5.9
# 3                 11            5.9
# 4                 11            5.9
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Extra Feature) days_since_ratio 추가

# %%
train_df['days_since_ratio'] = train_df.days_since_prior_order / train_df.user_avg_orders_period

# %%
train_df = train_df.merge(user_frequent_time, how = 'left', on='user_id')
train_df.head()
# Out:
#    user_id  order_id  product_id  products eval_set  order_number  order_dow  \
# 0        1   1187899       17122         0    train            11          4
# 1        1   1187899         196         1    train            11          4
# 2        1   1187899       26405         1    train            11          4
# 3        1   1187899       46149         1    train            11          4
# 4        1   1187899       14084         0    train            11          4
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0   ...     \
# 0                  8                    14.0                   1   ...
# 1                  8                    14.0                   1   ...
# 2                  8                    14.0                   1   ...
# 3                  8                    14.0                   1   ...
# 4                  8                    14.0                   1   ...
#
#    user_unique_products                               ordered_products_set  \
# 0                    18  {17122, 196, 26405, 46149, 14084, 13032, 26088...
# 1                    18  {17122, 196, 26405, 46149, 14084, 13032, 26088...
# 2                    18  {17122, 196, 26405, 46149, 14084, 13032, 26088...
# 3                    18  {17122, 196, 26405, 46149, 14084, 13032, 26088...
# 4                    18  {17122, 196, 26405, 46149, 14084, 13032, 26088...
#
#    user_avg_orders_period user_total_orders  user_avg_cart  days_since_ratio  \
# 0                    19.0                11            5.9          0.736842
# 1                    19.0                11            5.9          0.736842
# 2                    19.0                11            5.9          0.736842
# 3                    19.0                11            5.9          0.736842
# 4                    19.0                11            5.9          0.736842
#
#    0_count  1_count  2_count  3_count
# 0     True    False    False    False
# 1     True    False    False    False
# 2     True    False    False    False
# 3     True    False    False    False
# 4     True    False    False    False
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 4) UP(userXproduct) Information 추가

# %%
train_df['user_product'] = train_df.user_id * 100000 + train_df.product_id
train_df = train_df.merge(userXproduct, how='left', on='user_product')
train_df.drop(['user_product'], axis=1, inplace=True)

# %%
train_df['UP_orders_ratio'] = train_df.UP_orders / train_df.user_total_orders
train_df['UP_avg_pos_in_cart'] = train_df.UP_sum_pos_in_cart / train_df.UP_orders
train_df['UP_reorder_rate'] = train_df.UP_orders / train_df.user_total_orders
train_df['UP_orders_since_last'] = train_df.user_total_orders - train_df.UP_last_order_id.map(orders.order_number)
train_df['UP_delta_hour_vs_last'] = abs(train_df.order_hour_of_day - train_df.UP_last_order_id.map(orders.order_hour_of_day)).map(lambda x: min(x, 24-x))

train_df.head()
# Out:
#    user_id  order_id  product_id  products eval_set  order_number  order_dow  \
# 0        1   1187899       17122         0    train            11          4
# 1        1   1187899         196         1    train            11          4
# 2        1   1187899       26405         1    train            11          4
# 3        1   1187899       46149         1    train            11          4
# 4        1   1187899       14084         0    train            11          4
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# 0                  8                    14.0                   1
# 1                  8                    14.0                   1
# 2                  8                    14.0                   1
# 3                  8                    14.0                   1
# 4                  8                    14.0                   1
#
#            ...            2_count  3_count  UP_orders UP_last_order_id  \
# 0          ...              False    False          1           431534
# 1          ...              False    False         10          2550362
# 2          ...              False    False          2          2254736
# 3          ...              False    False          3          2550362
# 4          ...              False    False          1          2539329
#
#    UP_sum_pos_in_cart  UP_orders_ratio  UP_avg_pos_in_cart  UP_reorder_rate  \
# 0                   6         0.090909                 6.0         0.090909
# 1                  14         0.909091                 1.4         0.909091
# 2                  10         0.181818                 5.0         0.181818
# 3                   9         0.272727                 3.0         0.272727
# 4                   2         0.090909                 2.0         0.090909
#
#    UP_orders_since_last  UP_delta_hour_vs_last
# 0                     6                      7
# 1                     1                      0
# 2                     7                      1
# 3                     1                      0
# 4                    10                      0
#
# [5 rows x 38 columns]

# %% [markdown]
# ### 모든 데이터 통합 완료 & 사용할 attribute 선정

# %%
train_df.columns
# Out:
# Index(['user_id', 'order_id', 'product_id', 'products', 'eval_set',
#        'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order', 'categorized_hour_0', 'categorized_hour_1',
#        'categorized_hour_2', 'categorized_hour_3', 'product_name', 'aisle_id',
#        'department_id', 'product_orders', 'product_reorders',
#        'product_reorder_rate', 'user_total_products', 'user_unique_products',
#        'ordered_products_set', 'user_avg_orders_period', 'user_total_orders',
#        'user_avg_cart', 'days_since_ratio', '0_count', '1_count', '2_count',
#        '3_count', 'UP_orders', 'UP_last_order_id', 'UP_sum_pos_in_cart',
#        'UP_orders_ratio', 'UP_avg_pos_in_cart', 'UP_reorder_rate',
#        'UP_orders_since_last', 'UP_delta_hour_vs_last'],
#       dtype='object')

# %%
features = [
    # order information
    'categorized_hour_0', 'categorized_hour_1', 'categorized_hour_2', 'categorized_hour_3',
    'days_since_prior_order', 'days_since_ratio',
    # product information
    'aisle_id', 'department_id', 'product_orders', 'product_reorders', 'product_reorder_rate', 
    # user information
    'user_total_products', 'user_unique_products', 'user_avg_orders_period', 'user_total_orders', 'user_avg_cart', '0_count', '1_count', '2_count', '3_count', 
    # userXproduct information
    'UP_orders', 'UP_orders_ratio', 'UP_avg_pos_in_cart', 'UP_reorder_rate', 'UP_orders_since_last', 'UP_delta_hour_vs_last'
]

# %%
train_X = train_df[features]
train_y = train_df['products']

# %% [markdown]
# # 6. Test Data Generation

# %%
test_df = frame_test.copy()
test_df = test_df.merge(orders, how='left', on=['user_id','order_id'])
test_df = test_df.merge(Products, how='left', on='product_id')
test_df = test_df.merge(Users, how='left', on='user_id')

test_df['days_since_ratio'] = test_df.days_since_prior_order / test_df.user_avg_orders_period

test_df['user_product'] = test_df.user_id * 100000 + test_df.product_id
test_df = test_df.merge(userXproduct, how='left', on='user_product')
test_df.drop(['user_product'], axis=1, inplace=True)

test_df['UP_orders_ratio'] = test_df.UP_orders / test_df.user_total_orders
test_df['UP_avg_pos_in_cart'] = test_df.UP_sum_pos_in_cart / test_df.UP_orders
test_df['UP_reorder_rate'] = test_df.UP_orders / test_df.user_total_orders
test_df['UP_orders_since_last'] = test_df.user_total_orders - test_df.UP_last_order_id.map(orders.order_number)
test_df['UP_delta_hour_vs_last'] = abs(test_df.order_hour_of_day - test_df.UP_last_order_id.map(orders.order_hour_of_day)).map(lambda x: min(x, 24-x))

# %%
test_df = test_df.merge(user_frequent_time, how = 'left', on='user_id')
test_df.head()
# Out:
#    user_id  order_id  product_id eval_set  order_number  order_dow  \
# 0        3   2774568       17668     test            13          5
# 1        3   2774568       44683     test            13          5
# 2        3   2774568       48523     test            13          5
# 3        3   2774568       21903     test            13          5
# 4        3   2774568       14992     test            13          5
#
#    order_hour_of_day  days_since_prior_order  categorized_hour_0  \
# 0                 15                    11.0                   0
# 1                 15                    11.0                   0
# 2                 15                    11.0                   0
# 3                 15                    11.0                   0
# 4                 15                    11.0                   0
#
#    categorized_hour_1   ...     UP_sum_pos_in_cart  UP_orders_ratio  \
# 0                   0   ...                     18         0.384615
# 1                   0   ...                     19         0.153846
# 2                   0   ...                     13         0.153846
# 3                   0   ...                     34         0.615385
# 4                   0   ...                     14         0.153846
#
#   UP_avg_pos_in_cart  UP_reorder_rate  UP_orders_since_last  \
# 0               3.60         0.384615                     2
# 1               9.50         0.153846                     7
# 2               6.50         0.153846                     4
# 3               4.25         0.615385                     1
# 4               7.00         0.153846                     6
#
#    UP_delta_hour_vs_last  0_count  1_count  2_count  3_count
# 0                      3    False    False     True    False
# 1                      1    False    False     True    False
# 2                      1    False    False     True    False
# 3                      0    False    False     True    False
# 4                      0    False    False     True    False
#
# [5 rows x 37 columns]

# %%
test_X = test_df[features]

# %% [markdown]
# # 7. Learning & Prediction

# %%
import lightgbm as lgb

# %%
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': {'binary_logloss'},
    'num_leaves': 96,
    'max_depth': 10,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.95,
    'bagging_freq': 5
}
ROUNDS = 100

# %% [markdown]
# ### Learning

# %%
train_X_ds = lgb.Dataset(train_X, label=train_y, categorical_feature=['aisle_id','department_id'])

# %%
bst = lgb.train(params, train_X_ds, ROUNDS)

# %%
# %matplotlib inline 
lgb.plot_importance(bst, figsize=(9,20))

# %% [markdown]
# ### Prediction

# %%
result = bst.predict(test_X)

# %%
result = pd.concat([frame_test,pd.DataFrame(result, columns=['predict'])], axis=1)

# %%
result.head()
# Out:
#    user_id  order_id  product_id   predict
# 0        3   2774568       17668  0.351038
# 1        3   2774568       44683  0.069402
# 2        3   2774568       48523  0.089736
# 3        3   2774568       21903  0.647398
# 4        3   2774568       14992  0.081105

# %%
result
# Out:
#          user_id  order_id  product_id   predict
# 0              3   2774568       17668  0.351038
# 1              3   2774568       44683  0.069402
# 2              3   2774568       48523  0.089736
# 3              3   2774568       21903  0.647398
# 4              3   2774568       14992  0.081105
# 5              3   2774568       21137  0.074531
# 6              3   2774568       32402  0.195611
# 7              3   2774568       22035  0.159327
# 8              3   2774568       49683  0.047545
# 9              3   2774568       39190  0.766032
# 10             3   2774568       47766  0.714917
# 11             3   2774568       42265  0.059757
# 12             3   2774568        1819  0.106269
# 13             3   2774568       40604  0.040314
# 14             3   2774568       16797  0.175169
# 15             3   2774568       18599  0.301381
# 16             3   2774568       15143  0.022530
# 17             3   2774568        9387  0.131714
# 18             3   2774568       12845  0.028605
# 19             3   2774568       43961  0.316753
# 20             3   2774568       42557  0.052051
# 21             3   2774568       18370  0.044060
# 22             3   2774568       38596  0.026309
# 23             3   2774568       16965  0.058401
# 24             3   2774568       24010  0.082274
# 25             3   2774568        7503  0.033317
# 26             3   2774568        8021  0.045912
# 27             3   2774568       28373  0.067946
# 28             3   2774568       23650  0.387027
# 29             3   2774568       24810  0.285831
# ...          ...       ...         ...       ...
# 4833262   206208    803273       47008  0.018356
# 4833263   206208    803273       36772  0.034598
# 4833264   206208    803273       34213  0.743522
# 4833265   206208    803273        1463  0.191232
# 4833266   206208    803273       43961  0.198925
# 4833267   206208    803273       14778  0.226961
# 4833268   206208    803273       18880  0.024398
# 4833269   206208    803273       24009  0.016751
# 4833270   206208    803273       17355  0.019098
# 4833271   206208    803273       45007  0.169973
# 4833272   206208    803273        7632  0.016468
# 4833273   206208    803273       13775  0.004886
# 4833274   206208    803273       49621  0.012407
# 4833275   206208    803273       21461  0.010276
# 4833276   206208    803273       27608  0.009412
# 4833277   206208    803273       23516  0.008853
# 4833278   206208    803273       16349  0.011394
# 4833279   206208    803273       12252  0.006314
# 4833280   206208    803273       43999  0.023710
# 4833281   206208    803273       31717  0.227798
# 4833282   206208    803273       22504  0.030527
# 4833283   206208    803273       34282  0.072770
# 4833284   206208    803273       21996  0.017760
# 4833285   206208    803273        8174  0.018329
# 4833286   206208    803273       31215  0.020534
# 4833287   206208    803273       44532  0.017127
# 4833288   206208    803273       46069  0.154473
# 4833289   206208    803273       12791  0.023355
# 4833290   206208    803273       14332  0.014366
# 4833291   206208    803273        4605  0.040046
#
# [4833292 rows x 4 columns]

# %% [markdown]
# # 8. Prediction Probability 기반 최종 products list 생성

# %%
sorted_result = result.sort_values(['user_id', 'predict'], ascending=[True,False])

# %%
sorted_result.head()
# Out:
#     user_id  order_id  product_id   predict
# 9         3   2774568       39190  0.766032
# 10        3   2774568       47766  0.714917
# 3         3   2774568       21903  0.647398
# 28        3   2774568       23650  0.387027
# 0         3   2774568       17668  0.351038

# %%
sorted_result.reset_index(inplace=True)
sorted_result.drop(['index'], axis=1, inplace=True)
sorted_result.head()
# Out:
#    user_id  order_id  product_id   predict
# 0        3   2774568       39190  0.766032
# 1        3   2774568       47766  0.714917
# 2        3   2774568       21903  0.647398
# 3        3   2774568       23650  0.387027
# 4        3   2774568       17668  0.351038

# %%
sorted_result
# Out:
#          user_id  order_id  product_id   predict
# 0              3   2774568       39190  0.766032
# 1              3   2774568       47766  0.714917
# 2              3   2774568       21903  0.647398
# 3              3   2774568       23650  0.387027
# 4              3   2774568       17668  0.351038
# 5              3   2774568       43961  0.316753
# 6              3   2774568       18599  0.301381
# 7              3   2774568       24810  0.285831
# 8              3   2774568       32402  0.195611
# 9              3   2774568       16797  0.175169
# 10             3   2774568       22035  0.159327
# 11             3   2774568        9387  0.131714
# 12             3   2774568        1819  0.106269
# 13             3   2774568       48523  0.089736
# 14             3   2774568       24010  0.082274
# 15             3   2774568       14992  0.081105
# 16             3   2774568       21137  0.074531
# 17             3   2774568       44683  0.069402
# 18             3   2774568       28373  0.067946
# 19             3   2774568        1005  0.063383
# 20             3   2774568       42265  0.059757
# 21             3   2774568       16965  0.058401
# 22             3   2774568       42557  0.052051
# 23             3   2774568       49683  0.047545
# 24             3   2774568        8021  0.045912
# 25             3   2774568       18370  0.044060
# 26             3   2774568       40604  0.040314
# 27             3   2774568        7503  0.033317
# 28             3   2774568       12845  0.028605
# 29             3   2774568       39922  0.026397
# ...          ...       ...         ...       ...
# 4833262   206208    803273       26177  0.006817
# 4833263   206208    803273       31801  0.006668
# 4833264   206208    803273       36651  0.006652
# 4833265   206208    803273        7009  0.006566
# 4833266   206208    803273        7228  0.006425
# 4833267   206208    803273       12252  0.006314
# 4833268   206208    803273       29474  0.006259
# 4833269   206208    803273       46271  0.006132
# 4833270   206208    803273       42891  0.006072
# 4833271   206208    803273       41870  0.006006
# 4833272   206208    803273       27714  0.005784
# 4833273   206208    803273       38250  0.005498
# 4833274   206208    803273       31287  0.005290
# 4833275   206208    803273       46868  0.005276
# 4833276   206208    803273       49385  0.005208
# 4833277   206208    803273        5133  0.005181
# 4833278   206208    803273         165  0.005123
# 4833279   206208    803273       35217  0.005100
# 4833280   206208    803273       13775  0.004886
# 4833281   206208    803273          95  0.004881
# 4833282   206208    803273       25447  0.004863
# 4833283   206208    803273       42296  0.004591
# 4833284   206208    803273       29079  0.004519
# 4833285   206208    803273        4376  0.004479
# 4833286   206208    803273       41055  0.004383
# 4833287   206208    803273       22417  0.003623
# 4833288   206208    803273       47752  0.003276
# 4833289   206208    803273        8203  0.003232
# 4833290   206208    803273       28741  0.003063
# 4833291   206208    803273       15975  0.002800
#
# [4833292 rows x 4 columns]

# %%
ordered_products = sorted_result.groupby(['user_id', 'order_id'])['product_id'].apply(list)
ordered_products
# Out:
# user_id  order_id
# 3        2774568     [39190, 47766, 21903, 23650, 17668, 43961, 185...
# 4        329954      [26576, 21573, 35469, 25623, 25146, 19057, 376...
# 6        1528013     [21903, 38293, 8424, 27521, 45007, 25659, 4867...
# 11       1376945     [8309, 27959, 14947, 33572, 13176, 28465, 3465...
# 12       1356845     [13176, 10863, 7076, 14992, 28134, 11520, 2161...
# 15       2161313     [10441, 196, 14715, 12427, 27839, 37710, 48142...
# 16       1416320     [24852, 21903, 21137, 17948, 5134, 41950, 2456...
# 19       1735923     [17008, 34690, 31487, 35123, 15131, 12108, 219...
# 20       1980631       [13575, 9387, 22362, 46061, 6184, 13914, 41400]
# 22       139655      [27845, 22963, 22935, 17794, 35221, 13176, 249...
# 25       1411408     [22008, 43758, 26452, 10096, 37119, 27521, 121...
# 26       2940603     [19894, 44632, 30592, 14947, 31615, 10339, 185...
# 28       1192143     [24852, 47626, 35510, 27307, 49683, 8424, 2475...
# 31       280888      [32566, 19213, 41406, 35413, 12440, 13966, 459...
# 32       3202221     [24852, 9637, 4793, 49215, 17630, 21137, 11130...
# 33       3222866     [33198, 32912, 8501, 37131, 7969, 15718, 32441...
# 35       707453      [4942, 48230, 24852, 694, 18150, 21903, 32030,...
# 36       1320132     [44632, 22328, 12145, 47977, 39184, 33153, 442...
# 39       882556      [48679, 25890, 24852, 7371, 30962, 5450, 8424,...
# 40       2431024     [24799, 13176, 34217, 39928, 6975, 5699, 27555...
# 45       2827745     [17924, 47660, 43279, 27959, 47965, 20754, 207...
# 51       2174416     [15712, 36929, 18798, 10017, 13176, 40604, 476...
# 54       1325316     [26165, 47626, 24964, 24852, 38231, 47766, 120...
# 57       320326      [42828, 24852, 45646, 41896, 4302, 35163, 8193...
# 58       2128599     [14818, 622, 7628, 24703, 49227, 36750, 33219,...
# 60       1099519     [13176, 22035, 28058, 26351, 5428, 24838, 1679...
# 61       144494      [14947, 46260, 39108, 16959, 23106, 23431, 394...
# 68       3024191     [27521, 30233, 42450, 22260, 18362, 7948, 2638...
# 69       2817181     [18828, 41618, 19677, 28058, 1377, 22559, 4786...
# 73       2883656     [24852, 21497, 8193, 19660, 44661, 21137, 4039...
#                                            ...
# 206122   1968103     [2086, 4357, 49683, 40604, 41950, 3479, 8518, ...
# 206127   3094655     [37132, 31102, 32745, 21086, 45531, 49198, 132...
# 206131   2964171     [12564, 42450, 19660, 35584, 38580, 16223, 131...
# 206135   1522572     [24852, 47766, 27966, 21903, 3952, 43122, 1690...
# 206138   544857      [16797, 12341, 29223, 32478, 13176, 38768, 330...
# 206142   1421496     [11365, 37687, 12341, 21903, 39534, 14715, 179...
# 206143   765758      [38563, 18212, 24852, 536, 24954, 22124, 13203...
# 206147   1772796     [42445, 21903, 27845, 29447, 22825, 39408, 312...
# 206152   3177219     [30233, 21616, 35951, 34969, 8479, 19008, 3940...
# 206160   2380361     [12919, 30233, 1804, 432, 7693, 42719, 45374, ...
# 206161   928262      [39180, 21137, 11777, 10912, 1215, 36961, 2063...
# 206163   1722401        [21195, 48812, 5258, 19660, 34551, 7862, 6324]
# 206166   1945444     [22839, 22212, 14260, 33540, 44233, 6873, 5876...
# 206168   2000023     [25466, 27730, 3283, 38456, 47029, 48726, 3727...
# 206173   3151043     [15003, 5785, 29615, 40332, 9477, 12276, 49326...
# 206179   2900626     [27307, 49007, 36316, 26528, 32842, 38726, 355...
# 206180   2633505     [24852, 39332, 2295, 7280, 45066, 26604, 43726...
# 206182   1836967     [23909, 10279, 25570, 15324, 25830, 10890, 270...
# 206183   2799087     [24852, 27966, 45007, 47209, 43961, 21137, 456...
# 206187   2762353     [45842, 21405, 8555, 34429, 8277, 5652, 21982,...
# 206189   959487      [9623, 18205, 15902, 47209, 8021, 36724, 34991...
# 206192   701105      [24852, 42943, 17341, 8247, 13951, 21573, 2161...
# 206194   64567       [24852, 28204, 43740, 32740, 21709, 21903, 151...
# 206197   1564541     [30450, 17948, 21903, 48023, 42719, 29195, 213...
# 206201   309211      [23909, 21267, 34024, 41276, 38737, 294, 5782,...
# 206202   2728930     [24852, 2693, 17038, 21709, 12919, 38837, 432,...
# 206204   350108      [43961, 30561, 15649, 5646, 49075, 21137, 1019...
# 206206   1043943     [11520, 38530, 27086, 23029, 47011, 42623, 130...
# 206207   2821651     [44632, 13176, 36011, 39180, 33787, 27966, 278...
# 206208   803273      [34213, 13176, 21137, 33000, 27845, 23579, 314...
# Name: product_id, Length: 75000, dtype: object

# %%
d = dict()
for (uid, oid), row in ordered_products.iteritems():
    avg_cart = Users[Users.user_id == uid]['user_avg_cart'].values[0]
    
    row = row[:int(round(avg_cart))]
    
    for prod in row:    
        try:
            d[oid] += ' ' + str(prod)
        except:
            d[oid] = str(prod)

# %%
output = pd.DataFrame.from_dict(d, orient='index')
output.reset_index(inplace=True)
output.columns = ['order_id', 'products']
output.head()
# Out:
#    order_id                                           products
# 0   2774568          39190 47766 21903 23650 17668 43961 18599
# 1    329954                            26576 21573 35469 25623
# 2   1528013                       21903 38293 8424 27521 45007
# 3   1376945  8309 27959 14947 33572 13176 28465 34658 30563...
# 4   1356845  13176 10863 7076 14992 28134 11520 21616 22959...

# %%
output.to_csv('../submission/LightGBM-improving_userXproduct-insert_user_frequent_order_time.csv', index=False)
